# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description" : city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 2 | chapais
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | tvoroyri
# Processing Record 5 of Set 2 | kaitangata
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | chokurdakh
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | ishigaki
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | dubbo
# Processing Record 17 of Set 2 | rikitea
# Processing Record 18 of Set 2 | prince rupert
# Processing Record 19 of Set 2 | klaksvik
# Processing Record 20 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 2 | berlevag
# Processing Record 22 of Set 2 | evensk
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | bandar
# Processing Record 25 of Set 2 | necochea
# Processing Record 26 of Set 2 | chicama
# Processing Record 27 of Set 2 | karpogory
# Processing Record 28 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 2 | the valley
# Processing Record 30 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | bowen
# Processing Record 32 of Set 2 | srednekolymsk
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | guatire
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | port macquarie
# Processing Record 38 of Set 2 | viedma
# Processing Record 39 of Set 2 | saint leonard
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | kavaratti
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | punta arenas
# Processing Record 44 of Set 2 | tulum
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | astoria
# Processing Record 47 of Set 2 | sitka
# Processing Record 48 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | miraflores
# Processing Record 1 of Set 3 | husavik
# Processing Record 2 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | nagua
# Processing Record 5 of Set 3 | mildura
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 3 | syracuse
# Processing Record 10 of Set 3 | nouadhibou
# Processing Record 11 of Set 3 | tuatapere
# Processing Record 12 of Set 3 | waitara
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | ancud
# Processing Record 15 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 3 | faya
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | atuona
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | gat
# Processing Record 21 of Set 3 | jiwani
# Processing Record 22 of Set 3 | la rioja
# Processing Record 23 of Set 3 | carnarvon
# Processing Record 24 of Set 3 | roma
# Processing Record 25 of Set 3 | belmonte
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | noumea
# Processing Record 28 of Set 3 | covington
# Processing Record 29 of Set 3 | khatanga
# Processing Record 30 of Set 3 | broken hill
# Processing Record 31 of Set 3 | luderitz
# Processing Record 32 of Set 3 | ocampo
# Processing Record 33 of Set 3 | menongue
# Processing Record 34 of Set 3 | eureka
# Processing Record 35 of Set 3 | airai
# Processing Record 36 of Set 3 | narsaq
# Processing Record 37 of Set 3 | okhotsk
# Processing Record 38 of Set 3 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 39 of Set 3 | madimba
# Processing Record 40 of Set 3 | polunochnoye
# Processing Record 41 of Set 3 | dossor
# Processing Record 42 of Set 3 | barao de melgaco
# Processing Record 43 of Set 3 | ugoofaaru
# Processing Record 44 of Set 3 | utiel
# Processing Record 45 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 3 | grindavik
# Processing Record 47 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 3 | port alfred
# Processing Record 49 of Set 3 | yalta
# Processing Record 50 of Set 3 | east london
# Processing Record 1 of Set 4 | bayan
# Processing Record 2 of Set 4 | enshi
# Processing Record 3 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 4 | thompson
# Processing Record 5 of Set 4 | hami
# Processing Record 6 of Set 4 | furstenwalde
# Processing Record 7 of Set 4 | labuhan
# Processing Record 8 of Set 4 | upernavik
# Processing Record 9 of Set 4 | broome
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | xinyu
# Processing Record 12 of Set 4 | mount isa
# Processing Record 13 of Set 4 | auki
# Processing Record 14 of Set 4 | inongo
# Processing Record 15 of Set 4 | mount gambier
# Processing Record 16 of Set 4 | bethel
# Processing Record 17 of Set 4 | yulara
# Processing Record 18 of Set 4 | majene
# Processing Record 19 of Set 4 | hobart
# Processing Record 20 of Set 4 | deputatskiy
# Processing Record 21 of Set 4 | kirakira
# Processing Record 22 of Set 4 | kahului
# Processing Record 23 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | avarua
# Processing Record 26 of Set 4 | cuamba
# Processing Record 27 of Set 4 | scarborough
# Processing Record 28 of Set 4 | matara
# Processing Record 29 of Set 4 | longyearbyen
# Processing Record 30 of Set 4 | qaanaaq
# Processing Record 31 of Set 4 | sur
# Processing Record 32 of Set 4 | buraydah
# Processing Record 33 of Set 4 | vreed en hoop
# City not found. Skipping...
# Processing Record 34 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 4 | nome
# Processing Record 36 of Set 4 | kabompo
# Processing Record 37 of Set 4 | pontianak
# Processing Record 38 of Set 4 | winona
# Processing Record 39 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 40 of Set 4 | athabasca
# Processing Record 41 of Set 4 | port keats
# Processing Record 42 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 4 | hithadhoo
# Processing Record 44 of Set 4 | puerto ayora
# Processing Record 45 of Set 4 | port elizabeth
# Processing Record 46 of Set 4 | marzuq
# Processing Record 47 of Set 4 | severo-kurilsk
# Processing Record 48 of Set 4 | cidreira
# Processing Record 49 of Set 4 | esna
# Processing Record 50 of Set 4 | lasa
# Processing Record 1 of Set 5 | marsa matruh
# Processing Record 2 of Set 5 | lebu
# Processing Record 3 of Set 5 | bubaque
# Processing Record 4 of Set 5 | edd
# Processing Record 5 of Set 5 | hualmay
# Processing Record 6 of Set 5 | mocajuba
# Processing Record 7 of Set 5 | bealanana
# Processing Record 8 of Set 5 | durban
# Processing Record 9 of Set 5 | kieta
# Processing Record 10 of Set 5 | katsuura
# Processing Record 11 of Set 5 | tasiilaq
# Processing Record 12 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 5 | ilulissat
# Processing Record 14 of Set 5 | san cristobal
# Processing Record 15 of Set 5 | benxi
# Processing Record 16 of Set 5 | nanortalik
# Processing Record 17 of Set 5 | hilo
# Processing Record 18 of Set 5 | ahuimanu
# Processing Record 19 of Set 5 | dunedin
# Processing Record 20 of Set 5 | tazovskiy
# Processing Record 21 of Set 5 | bengkulu
# Processing Record 22 of Set 5 | iqaluit
# Processing Record 23 of Set 5 | tura
# Processing Record 24 of Set 5 | sao filipe
# Processing Record 25 of Set 5 | rutland
# Processing Record 26 of Set 5 | tamandare
# Processing Record 27 of Set 5 | frumoasa
# Processing Record 28 of Set 5 | adre
# Processing Record 29 of Set 5 | victoria
# Processing Record 30 of Set 5 | mahebourg
# Processing Record 31 of Set 5 | hasaki
# Processing Record 32 of Set 5 | vilyuysk
# Processing Record 33 of Set 5 | arraial do cabo
# Processing Record 34 of Set 5 | isangel
# Processing Record 35 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 5 | kandava
# Processing Record 37 of Set 5 | sept-iles
# Processing Record 38 of Set 5 | shenjiamen
# Processing Record 39 of Set 5 | orillia
# Processing Record 40 of Set 5 | bafq
# Processing Record 41 of Set 5 | riviere-au-renard
# Processing Record 42 of Set 5 | yellowknife
# Processing Record 43 of Set 5 | piet retief
# Processing Record 44 of Set 5 | saint george
# Processing Record 45 of Set 5 | mandera
# Processing Record 46 of Set 5 | linxia
# Processing Record 47 of Set 5 | hervey bay
# Processing Record 48 of Set 5 | walvis bay
# Processing Record 49 of Set 5 | outjo
# Processing Record 50 of Set 5 | akhtubinsk
# Processing Record 1 of Set 6 | papara
# Processing Record 2 of Set 6 | tsumeb
# Processing Record 3 of Set 6 | usinsk
# Processing Record 4 of Set 6 | pevek
# Processing Record 5 of Set 6 | mesyagutovo
# Processing Record 6 of Set 6 | tateyama
# Processing Record 7 of Set 6 | rio grande
# Processing Record 8 of Set 6 | saint-philippe
# Processing Record 9 of Set 6 | rypefjord
# Processing Record 10 of Set 6 | tczew
# Processing Record 11 of Set 6 | touros
# Processing Record 12 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 6 | meadow lake
# Processing Record 14 of Set 6 | nikolskoye
# Processing Record 15 of Set 6 | belyy yar
# Processing Record 16 of Set 6 | flin flon
# Processing Record 17 of Set 6 | olafsvik
# Processing Record 18 of Set 6 | bushehr
# Processing Record 19 of Set 6 | bogandinskiy
# Processing Record 20 of Set 6 | san rafael
# Processing Record 21 of Set 6 | hirara
# Processing Record 22 of Set 6 | cabo san lucas
# Processing Record 23 of Set 6 | kalmunai
# Processing Record 24 of Set 6 | vanavara
# Processing Record 25 of Set 6 | te anau
# Processing Record 26 of Set 6 | salalah
# Processing Record 27 of Set 6 | sechura
# Processing Record 28 of Set 6 | caravelas
# Processing Record 29 of Set 6 | bathsheba
# Processing Record 30 of Set 6 | new norfolk
# Processing Record 31 of Set 6 | magadan
# Processing Record 32 of Set 6 | torbay
# Processing Record 33 of Set 6 | hambantota
# Processing Record 34 of Set 6 | thessalon
# Processing Record 35 of Set 6 | sikeston
# Processing Record 36 of Set 6 | svetlogorsk
# Processing Record 37 of Set 6 | mananjary
# Processing Record 38 of Set 6 | baykit
# Processing Record 39 of Set 6 | talnakh
# Processing Record 40 of Set 6 | imeni poliny osipenko
# Processing Record 41 of Set 6 | orange cove
# Processing Record 42 of Set 6 | tugulym
# Processing Record 43 of Set 6 | lensk
# Processing Record 44 of Set 6 | saint-augustin
# Processing Record 45 of Set 6 | moose factory
# Processing Record 46 of Set 6 | port moresby
# Processing Record 47 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 6 | san jose
# Processing Record 49 of Set 6 | gorele
# Processing Record 50 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 7 | bathurst
# Processing Record 2 of Set 7 | akdepe
# Processing Record 3 of Set 7 | richards bay
# Processing Record 4 of Set 7 | muros
# Processing Record 5 of Set 7 | namibe
# Processing Record 6 of Set 7 | presidencia roque saenz pena
# Processing Record 7 of Set 7 | slave lake
# Processing Record 8 of Set 7 | gizo
# Processing Record 9 of Set 7 | kapit
# Processing Record 10 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 12 of Set 7 | agirish
# Processing Record 13 of Set 7 | gao
# Processing Record 14 of Set 7 | wainwright
# Processing Record 15 of Set 7 | honningsvag
# Processing Record 16 of Set 7 | zhuanghe
# Processing Record 17 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 7 | ayan
# Processing Record 20 of Set 7 | manoel urbano
# Processing Record 21 of Set 7 | kiama
# Processing Record 22 of Set 7 | constitucion
# Processing Record 23 of Set 7 | pisco
# Processing Record 24 of Set 7 | kamenka
# Processing Record 25 of Set 7 | saldanha
# Processing Record 26 of Set 7 | souillac
# Processing Record 27 of Set 7 | beidao
# Processing Record 28 of Set 7 | srinagar
# Processing Record 29 of Set 7 | provideniya
# Processing Record 30 of Set 7 | rocha
# Processing Record 31 of Set 7 | planadas
# Processing Record 32 of Set 7 | clyde river
# Processing Record 33 of Set 7 | brae
# Processing Record 34 of Set 7 | lorengau
# Processing Record 35 of Set 7 | marawi
# Processing Record 36 of Set 7 | port blair
# Processing Record 37 of Set 7 | werda
# Processing Record 38 of Set 7 | pacific grove
# Processing Record 39 of Set 7 | namatanai
# Processing Record 40 of Set 7 | cairns
# Processing Record 41 of Set 7 | waddan
# Processing Record 42 of Set 7 | trairi
# Processing Record 43 of Set 7 | waw
# Processing Record 44 of Set 7 | zhigansk
# Processing Record 45 of Set 7 | henties bay
# Processing Record 46 of Set 7 | jaguariaiva
# Processing Record 47 of Set 7 | mayo
# Processing Record 48 of Set 7 | leningradskiy
# Processing Record 49 of Set 7 | havelock
# Processing Record 50 of Set 7 | fortuna
# Processing Record 1 of Set 8 | kobojango
# City not found. Skipping...
# Processing Record 2 of Set 8 | kjopsvik
# Processing Record 3 of Set 8 | oyama
# Processing Record 4 of Set 8 | veraval
# Processing Record 5 of Set 8 | la asuncion
# Processing Record 6 of Set 8 | san ramon
# Processing Record 7 of Set 8 | meulaboh
# Processing Record 8 of Set 8 | rio brilhante
# Processing Record 9 of Set 8 | togur
# Processing Record 10 of Set 8 | pitimbu
# Processing Record 11 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 8 | los llanos de aridane
# Processing Record 13 of Set 8 | zwedru
# Processing Record 14 of Set 8 | springbok
# Processing Record 15 of Set 8 | alekseyevka
# Processing Record 16 of Set 8 | phonhong
# Processing Record 17 of Set 8 | sakakah
# Processing Record 18 of Set 8 | asayita
# City not found. Skipping...
# Processing Record 19 of Set 8 | tahe
# Processing Record 20 of Set 8 | klamath falls
# Processing Record 21 of Set 8 | finnsnes
# Processing Record 22 of Set 8 | santiago del estero
# Processing Record 23 of Set 8 | matay
# Processing Record 24 of Set 8 | port-gentil
# Processing Record 25 of Set 8 | ostrovnoy
# Processing Record 26 of Set 8 | port lincoln
# Processing Record 27 of Set 8 | saravan
# Processing Record 28 of Set 8 | panama city
# Processing Record 29 of Set 8 | codrington
# Processing Record 30 of Set 8 | jishu
# Processing Record 31 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 32 of Set 8 | kajaani
# Processing Record 33 of Set 8 | vila velha
# Processing Record 34 of Set 8 | iranshahr
# Processing Record 35 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 8 | fort nelson
# Processing Record 37 of Set 8 | zonguldak
# Processing Record 38 of Set 8 | mazyr
# Processing Record 39 of Set 8 | pangnirtung
# Processing Record 40 of Set 8 | charters towers
# Processing Record 41 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 8 | coquimbo
# Processing Record 43 of Set 8 | grand gaube
# Processing Record 44 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 45 of Set 8 | comodoro rivadavia
# Processing Record 46 of Set 8 | aysha
# Processing Record 47 of Set 8 | cabedelo
# Processing Record 48 of Set 8 | hovd
# Processing Record 49 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 50 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 1 of Set 9 | ayagoz
# Processing Record 2 of Set 9 | portobelo
# Processing Record 3 of Set 9 | yalvac
# Processing Record 4 of Set 9 | riyadh
# Processing Record 5 of Set 9 | bedele
# Processing Record 6 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 7 of Set 9 | catamarca
# Processing Record 8 of Set 9 | isiolo
# Processing Record 9 of Set 9 | saskylakh
# Processing Record 10 of Set 9 | naliya
# Processing Record 11 of Set 9 | kargasok
# Processing Record 12 of Set 9 | westport
# Processing Record 13 of Set 9 | kimberley
# Processing Record 14 of Set 9 | aklavik
# Processing Record 15 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 9 | mogadishu
# Processing Record 17 of Set 9 | anchorage
# Processing Record 18 of Set 9 | balabac
# Processing Record 19 of Set 9 | hofn
# Processing Record 20 of Set 9 | huarmey
# Processing Record 21 of Set 9 | guerrero negro
# Processing Record 22 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 9 | pochutla
# Processing Record 24 of Set 9 | bage
# Processing Record 25 of Set 9 | pangody
# Processing Record 26 of Set 9 | burnie
# Processing Record 27 of Set 9 | coacoyul
# Processing Record 28 of Set 9 | lyngseidet
# Processing Record 29 of Set 9 | toora-khem
# Processing Record 30 of Set 9 | ponta delgada
# Processing Record 31 of Set 9 | komsomolskiy
# Processing Record 32 of Set 9 | asau
# Processing Record 33 of Set 9 | dhanera
# Processing Record 34 of Set 9 | kruisfontein
# Processing Record 35 of Set 9 | coralville
# Processing Record 36 of Set 9 | faanui
# Processing Record 37 of Set 9 | biak
# Processing Record 38 of Set 9 | chifeng
# Processing Record 39 of Set 9 | sola
# Processing Record 40 of Set 9 | sao lourenco do sul
# Processing Record 41 of Set 9 | waingapu
# Processing Record 42 of Set 9 | charagua
# Processing Record 43 of Set 9 | mandurah
# Processing Record 44 of Set 9 | kuruman
# Processing Record 45 of Set 9 | staryy nadym
# Processing Record 46 of Set 9 | cherskiy
# Processing Record 47 of Set 9 | darhan
# Processing Record 48 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 9 | inuvik
# Processing Record 50 of Set 9 | taltal
# Processing Record 1 of Set 10 | norman wells
# Processing Record 2 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 3 of Set 10 | simbahan
# Processing Record 4 of Set 10 | timiryazevskiy
# Processing Record 5 of Set 10 | kommunisticheskiy
# Processing Record 6 of Set 10 | lavrentiya
# Processing Record 7 of Set 10 | laguna
# Processing Record 8 of Set 10 | gobabis
# Processing Record 9 of Set 10 | tomatlan
# Processing Record 10 of Set 10 | tessalit
# Processing Record 11 of Set 10 | newport
# Processing Record 12 of Set 10 | antofagasta
# Processing Record 13 of Set 10 | puerto ayacucho
# Processing Record 14 of Set 10 | mahuva
# Processing Record 15 of Set 10 | beyneu
# Processing Record 16 of Set 10 | half moon bay
# Processing Record 17 of Set 10 | shenzhen
# Processing Record 18 of Set 10 | fare
# Processing Record 19 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 10 | craig
# Processing Record 21 of Set 10 | bambanglipuro
# Processing Record 22 of Set 10 | bilma
# Processing Record 23 of Set 10 | seydi
# Processing Record 24 of Set 10 | rechitsy
# Processing Record 25 of Set 10 | san quintin
# Processing Record 26 of Set 10 | pinega
# Processing Record 27 of Set 10 | mpika
# Processing Record 28 of Set 10 | rio bueno
# Processing Record 29 of Set 10 | gorontalo
# Processing Record 30 of Set 10 | druzhba
# Processing Record 31 of Set 10 | boralday
# Processing Record 32 of Set 10 | kostroma
# Processing Record 33 of Set 10 | barahan
# Processing Record 34 of Set 10 | gairatganj
# Processing Record 35 of Set 10 | blythe
# Processing Record 36 of Set 10 | nabire
# Processing Record 37 of Set 10 | bangsund
# Processing Record 38 of Set 10 | avera
# Processing Record 39 of Set 10 | babina
# Processing Record 40 of Set 10 | millinocket
# Processing Record 41 of Set 10 | muravlenko
# Processing Record 42 of Set 10 | ballina
# Processing Record 43 of Set 10 | onega
# Processing Record 44 of Set 10 | durango
# Processing Record 45 of Set 10 | muroto
# Processing Record 46 of Set 10 | nsanje
# Processing Record 47 of Set 10 | ilo
# Processing Record 48 of Set 10 | lata
# Processing Record 49 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 10 | murdochville
# Processing Record 1 of Set 11 | doha
# Processing Record 2 of Set 11 | coihaique
# Processing Record 3 of Set 11 | naze
# Processing Record 4 of Set 11 | teguise
# Processing Record 5 of Set 11 | sinnamary
# Processing Record 6 of Set 11 | liverpool
# Processing Record 7 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 11 | vila franca do campo
# Processing Record 9 of Set 11 | padang
# Processing Record 10 of Set 11 | yarensk
# Processing Record 11 of Set 11 | araouane
# Processing Record 12 of Set 11 | andenes
# Processing Record 13 of Set 11 | omboue
# Processing Record 14 of Set 11 | buala
# Processing Record 15 of Set 11 | zhuhai
# Processing Record 16 of Set 11 | singapore
# Processing Record 17 of Set 11 | lompoc
# Processing Record 18 of Set 11 | bonavista
# Processing Record 19 of Set 11 | rindal
# Processing Record 20 of Set 11 | charcas
# Processing Record 21 of Set 11 | vostok
# Processing Record 22 of Set 11 | la ronge
# Processing Record 23 of Set 11 | casper
# Processing Record 24 of Set 11 | yermakovskoye
# Processing Record 25 of Set 11 | soyo
# Processing Record 26 of Set 11 | calvinia
# Processing Record 27 of Set 11 | nurota
# Processing Record 28 of Set 11 | owando
# Processing Record 29 of Set 11 | vestmannaeyjar
# Processing Record 30 of Set 11 | livramento
# Processing Record 31 of Set 11 | yamada
# Processing Record 32 of Set 11 | dawson
# Processing Record 33 of Set 11 | shimoda
# Processing Record 34 of Set 11 | mineiros
# Processing Record 35 of Set 11 | lop buri
# Processing Record 36 of Set 11 | canitas
# City not found. Skipping...
# Processing Record 37 of Set 11 | yuli
# Processing Record 38 of Set 11 | hassleholm
# Processing Record 39 of Set 11 | zyryanka
# Processing Record 40 of Set 11 | almaznyy
# Processing Record 41 of Set 11 | mantua
# Processing Record 42 of Set 11 | krasnogorodsk
# Processing Record 43 of Set 11 | indramayu
# Processing Record 44 of Set 11 | umm kaddadah
# Processing Record 45 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 11 | varhaug
# Processing Record 47 of Set 11 | price
# Processing Record 48 of Set 11 | yar-sale
# Processing Record 49 of Set 11 | davila
# Processing Record 50 of Set 11 | robertsport
# Processing Record 1 of Set 12 | takoradi
# Processing Record 2 of Set 12 | dawei
# Processing Record 3 of Set 12 | hamilton
# Processing Record 4 of Set 12 | san policarpo
# Processing Record 5 of Set 12 | kloulklubed
# Processing Record 6 of Set 12 | verkhnevilyuysk
# Processing Record 7 of Set 12 | christchurch
# Processing Record 8 of Set 12 | poiana marului
# Processing Record 9 of Set 12 | cap malheureux
# Processing Record 10 of Set 12 | dingle
# Processing Record 11 of Set 12 | port-de-paix
# City not found. Skipping...
# Processing Record 12 of Set 12 | berdyuzhye
# City not found. Skipping...
# Processing Record 13 of Set 12 | ojuelos de jalisco
# Processing Record 14 of Set 12 | anyksciai
# Processing Record 15 of Set 12 | mersin
# Processing Record 16 of Set 12 | de aar
# Processing Record 17 of Set 12 | chipinge
# Processing Record 18 of Set 12 | hobyo
# Processing Record 19 of Set 12 | kismayo
# Processing Record 20 of Set 12 | senneterre
# Processing Record 21 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 22 of Set 12 | marsaxlokk
# Processing Record 23 of Set 12 | colac
# Processing Record 24 of Set 12 | dicabisagan
# Processing Record 25 of Set 12 | samarai
# Processing Record 26 of Set 12 | abha
# Processing Record 27 of Set 12 | porto santo
# Processing Record 28 of Set 12 | wagar
# Processing Record 29 of Set 12 | misratah
# Processing Record 30 of Set 12 | ouesso
# Processing Record 31 of Set 12 | esperance
# Processing Record 32 of Set 12 | chihuahua
# Processing Record 33 of Set 12 | port hardy
# Processing Record 34 of Set 12 | miri
# Processing Record 35 of Set 12 | wilmington
# Processing Record 36 of Set 12 | mariental
# Processing Record 37 of Set 12 | uusikaupunki
# Processing Record 38 of Set 12 | mackenzie
# Processing Record 39 of Set 12 | vite
# Processing Record 40 of Set 12 | guinguineo
# Processing Record 41 of Set 12 | pemangkat
# Processing Record 42 of Set 12 | abnub
# Processing Record 43 of Set 12 | portland
# Processing Record 44 of Set 12 | tiznit
# Processing Record 45 of Set 12 | khandyga
# Processing Record 46 of Set 12 | okha
# Processing Record 47 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 48 of Set 12 | chernushka
# Processing Record 49 of Set 12 | keningau
# Processing Record 50 of Set 12 | nkhotakota
# Processing Record 1 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 13 | alofi
# Processing Record 3 of Set 13 | naryan-mar
# Processing Record 4 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 13 | zaysan
# Processing Record 6 of Set 13 | itarema
# Processing Record 7 of Set 13 | salina
# Processing Record 8 of Set 13 | santa barbara
# Processing Record 9 of Set 13 | zheshart
# Processing Record 10 of Set 13 | taganak
# Processing Record 11 of Set 13 | saint anthony
# Processing Record 12 of Set 13 | mahajanga
# Processing Record 13 of Set 13 | ca mau
# Processing Record 14 of Set 13 | wanxian
# Processing Record 15 of Set 13 | idrinskoye
# Processing Record 16 of Set 13 | songkhla
# Processing Record 17 of Set 13 | kosino
# Processing Record 18 of Set 13 | gamba
# Processing Record 19 of Set 13 | vuktyl
# Processing Record 20 of Set 13 | liaoyang
# Processing Record 21 of Set 13 | bambous virieux
# Processing Record 22 of Set 13 | solnechnyy
# Processing Record 23 of Set 13 | manono
# Processing Record 24 of Set 13 | quatre cocos
# Processing Record 25 of Set 13 | humboldt
# Processing Record 26 of Set 13 | vao
# Processing Record 27 of Set 13 | ponta do sol
# Processing Record 28 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 29 of Set 13 | afua
# Processing Record 30 of Set 13 | kununurra
# Processing Record 31 of Set 13 | vagur
# Processing Record 32 of Set 13 | arman
# Processing Record 33 of Set 13 | san patricio
# Processing Record 34 of Set 13 | goderich
# Processing Record 35 of Set 13 | sambava
# Processing Record 36 of Set 13 | cotonou
# Processing Record 37 of Set 13 | igdir
# Processing Record 38 of Set 13 | cape girardeau
# Processing Record 39 of Set 13 | gwadar
# Processing Record 40 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 41 of Set 13 | bonfim
# Processing Record 42 of Set 13 | camana
# Processing Record 43 of Set 13 | ambovombe
# Processing Record 44 of Set 13 | carroll
# Processing Record 45 of Set 13 | ranong
# Processing Record 46 of Set 13 | popova
# Processing Record 47 of Set 13 | fairbanks
# Processing Record 48 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 13 | rayadrug
# Processing Record 50 of Set 13 | katima mulilo
# Processing Record 1 of Set 14 | oktyabrskiy
# Processing Record 2 of Set 14 | san miguel
# Processing Record 3 of Set 14 | mopti
# Processing Record 4 of Set 14 | morondava
# Processing Record 5 of Set 14 | cortez
# Processing Record 6 of Set 14 | sorland
# Processing Record 7 of Set 14 | daru
# Processing Record 8 of Set 14 | bogorodskoye
# Processing Record 9 of Set 14 | yining
# Processing Record 10 of Set 14 | buchanan
# Processing Record 11 of Set 14 | bilibino
# Processing Record 12 of Set 14 | mazatlan
# Processing Record 13 of Set 14 | witney
# Processing Record 14 of Set 14 | putina
# Processing Record 15 of Set 14 | mozarlandia
# Processing Record 16 of Set 14 | launceston
# Processing Record 17 of Set 14 | kota kinabalu
# Processing Record 18 of Set 14 | sibenik
# Processing Record 19 of Set 14 | havre-saint-pierre
# Processing Record 20 of Set 14 | virudunagar
# Processing Record 21 of Set 14 | pindiga
# Processing Record 22 of Set 14 | strathmore
# Processing Record 23 of Set 14 | tsabong
# Processing Record 24 of Set 14 | ulety
# Processing Record 25 of Set 14 | mafinga
# Processing Record 26 of Set 14 | makakilo city
# Processing Record 27 of Set 14 | moyobamba
# Processing Record 28 of Set 14 | vardo
# Processing Record 29 of Set 14 | sayansk
# Processing Record 30 of Set 14 | high rock
# Processing Record 31 of Set 14 | cairo
# Processing Record 32 of Set 14 | sisimiut
# Processing Record 33 of Set 14 | santa maria
# Processing Record 34 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 14 | san mateo del mar
# Processing Record 36 of Set 14 | coahuayana
# Processing Record 37 of Set 14 | bay city
# Processing Record 38 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 14 | viesca
# Processing Record 40 of Set 14 | port shepstone
# Processing Record 41 of Set 14 | esso
# Processing Record 42 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 14 | korla
# Processing Record 44 of Set 14 | garissa
# Processing Record 45 of Set 14 | manokwari
# Processing Record 46 of Set 14 | sao felix do xingu
# Processing Record 47 of Set 14 | uva
# Processing Record 48 of Set 14 | myrtle beach
# Processing Record 49 of Set 14 | praxedis guerrero
# Processing Record 50 of Set 14 | tuyen quang
# Processing Record 1 of Set 15 | puerto escondido
# Processing Record 2 of Set 15 | jumla
# Processing Record 3 of Set 15 | seymchan
# Processing Record 4 of Set 15 | goianesia
# Processing Record 5 of Set 15 | lahij
# Processing Record 6 of Set 15 | beberibe
# Processing Record 7 of Set 15 | matagami
# Processing Record 8 of Set 15 | panzhihua
# Processing Record 9 of Set 15 | bainbridge
# Processing Record 10 of Set 15 | uyuni
# Processing Record 11 of Set 15 | sar-e pul
# Processing Record 12 of Set 15 | belle fourche
# Processing Record 13 of Set 15 | pula
# Processing Record 14 of Set 15 | san carlos de bariloche
# Processing Record 15 of Set 15 | ixcaquixtla
# City not found. Skipping...
# Processing Record 16 of Set 15 | melita
# Processing Record 17 of Set 15 | huejuquilla el alto
# Processing Record 18 of Set 15 | saint-joseph
# Processing Record 19 of Set 15 | navoi
# Processing Record 20 of Set 15 | borba
# Processing Record 21 of Set 15 | naron
# Processing Record 22 of Set 15 | chimbote
# Processing Record 23 of Set 15 | katobu
# Processing Record 24 of Set 15 | tual
# Processing Record 25 of Set 15 | lar gerd
# City not found. Skipping...
# Processing Record 26 of Set 15 | college
# Processing Record 27 of Set 15 | turukhansk
# Processing Record 28 of Set 15 | aksarka
# Processing Record 29 of Set 15 | ostersund
# Processing Record 30 of Set 15 | puerto del rosario
# Processing Record 31 of Set 15 | palana
# Processing Record 32 of Set 15 | atar
# Processing Record 33 of Set 15 | kodiak
# Processing Record 34 of Set 15 | florenville
# Processing Record 35 of Set 15 | ouallam
# Processing Record 36 of Set 15 | beckley
# Processing Record 37 of Set 15 | nhulunbuy
# Processing Record 38 of Set 15 | juneau
# Processing Record 39 of Set 15 | nchelenge
# Processing Record 40 of Set 15 | karratha
# Processing Record 41 of Set 15 | adamas
# Processing Record 42 of Set 15 | nortelandia
# Processing Record 43 of Set 15 | luanda
# Processing Record 44 of Set 15 | macouria
# Processing Record 45 of Set 15 | port hawkesbury
# Processing Record 46 of Set 15 | lazaro cardenas
# Processing Record 47 of Set 15 | haines junction
# Processing Record 48 of Set 15 | sao joao da barra
# Processing Record 49 of Set 15 | laramie
# Processing Record 50 of Set 15 | gigmoto
# Processing Record 1 of Set 16 | ballarat
# Processing Record 2 of Set 16 | palauig
# Processing Record 3 of Set 16 | baruun-urt
# Processing Record 4 of Set 16 | chumikan
# Processing Record 5 of Set 16 | shingu
# Processing Record 6 of Set 16 | xinzhou
# Processing Record 7 of Set 16 | saint-francois
# Processing Record 8 of Set 16 | baberu
# Processing Record 9 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 16 | baijiantan
# Processing Record 11 of Set 16 | sajanan
# Processing Record 12 of Set 16 | japura
# Processing Record 13 of Set 16 | gimli
# Processing Record 14 of Set 16 | vila do maio
# Processing Record 15 of Set 16 | udachnyy
# Processing Record 16 of Set 16 | xapuri
# Processing Record 17 of Set 16 | leshukonskoye
# Processing Record 18 of Set 16 | lisakovsk
# Processing Record 19 of Set 16 | novopokrovka
# Processing Record 20 of Set 16 | tabou
# Processing Record 21 of Set 16 | purpe
# Processing Record 22 of Set 16 | mirzapur
# Processing Record 23 of Set 16 | lerwick
# Processing Record 24 of Set 16 | cururupu
# Processing Record 25 of Set 16 | khorramshahr
# Processing Record 26 of Set 16 | mandalgovi
# Processing Record 27 of Set 16 | levelland
# Processing Record 28 of Set 16 | gazli
# Processing Record 29 of Set 16 | jaisalmer
# Processing Record 30 of Set 16 | rudsar
# Processing Record 31 of Set 16 | sioux lookout
# Processing Record 32 of Set 16 | amahai
# Processing Record 33 of Set 16 | zaragoza
# Processing Record 34 of Set 16 | masuri
# Processing Record 35 of Set 16 | harper
# Processing Record 36 of Set 16 | sayyan
# Processing Record 37 of Set 16 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 16 | tocopilla
# Processing Record 39 of Set 16 | champerico
# Processing Record 40 of Set 16 | paita
# Processing Record 41 of Set 16 | xingcheng
# Processing Record 42 of Set 16 | texarkana
# Processing Record 43 of Set 16 | east stroudsburg
# Processing Record 44 of Set 16 | chernyshevskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Chapais  49.7834  -74.8492     56.98        96         100        2.59
# 1    Hermanus -34.4187   19.2345     56.80        53          15        7.36
# 2       Bluff -46.6000  168.3333     50.81        73           8        8.57
# 3    Tvoroyri  61.5556   -6.8111     50.45        92          90       15.17
# 4  Kaitangata -46.2817  169.8464     53.71        66           0        3.53
# 5     Ushuaia -54.8000  -68.3000     35.83        86          85       13.33
# 6      Albany  42.6001  -73.9662     73.63        39          11        6.73
# 7  Chokurdakh  70.6333  147.9167     53.13        33          32        9.64
# 8        Chuy -33.6971  -53.4616     57.43        92         100        4.18
# 9  Butaritari   3.0707  172.7902     81.55        74          78       13.13
#
#   Country                 Date Current Description
# 0      CA  2022-06-05 23:31:38     overcast clouds
# 1      ZA  2022-06-05 23:30:49          few clouds
# 2      NZ  2022-06-05 23:31:39           clear sky
# 3      FO  2022-06-05 23:31:39     overcast clouds
# 4      NZ  2022-06-05 23:31:40           clear sky
# 5      AR  2022-06-05 23:30:36     overcast clouds
# 6      US  2022-06-05 23:27:42          few clouds
# 7      RU  2022-06-05 23:31:40    scattered clouds
# 8      UY  2022-06-05 23:31:40     overcast clouds
# 9      KI  2022-06-05 23:31:41       broken clouds

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]
city_data_df = city_data_df[new_column_order]

# %%
# Drop date column
city_data_df = city_data_df.drop(columns=["Date"])
city_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1136\3586747614.py in <module>
#       1 # Drop date column
# ----> 2 city_data_df = city_data_df.drop(columns=["Date"])
#       3 city_data_df.head()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Date'] not found in axis"

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
